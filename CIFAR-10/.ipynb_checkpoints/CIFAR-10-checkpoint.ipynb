# %%
#Importing basic library

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers,models
import matplotlib.pyplot as plt

# %%
#Load the data

(x_train, y_train) , (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train:", x_train.shape, "| Test:", x_test.shape)
print("Pixel range:", x_train.min(), "to", x_train.max())
print("Labels shape:", y_train.shape)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\datasets\cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Train: (50000, 32, 32, 3) | Test: (10000, 32, 32, 3)
# Pixel range: 0 to 255
# Labels shape: (50000, 1)

# %%
#Normalizing the training data

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

print(f"After normalizing, training pixel reange is {x_train.min()} to {x_train.max()}")
# Out:
# After normalizing, training pixel reange is 0.0 to 1.0

# %%
plt.figure(figsize=(10,4))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]],fontsize = 8)
    plt.axis = "off"
plt.tight_layout()
plt.show()

# %%
#Model building

model = models.Sequential([
    layers.Conv2D( 32 , (3,3) , activation="relu" , padding="same" , input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Conv2D( 64 , (3,3) , activation="relu" , padding="same" ),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),
    layers.Conv2D( 128 , (3,3) , activation="relu" , padding="same" ),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),

    layers.Flatten(),
    layers.Dropout(0.25),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.25),
    layers.Dense(10 , activation="softmax")
])
model.summary ()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 357,706 (1.36 MB)
#  Trainable params: 357,258 (1.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range = 15,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = True
)

datagen.fit(x_train)

model.compile(
    optimizer = "Adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["Accuracy"]
)

history = model.fit(
    datagen.flow(x_train,y_train,batch_size=64),
    epochs = 40,
    validation_data = (x_test,y_test),
    callbacks = [
        tf.keras.callbacks.EarlyStopping( patience = 5 , restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau( patience = 3 , factore = 0.5 , verbose = 1)
    ]
)

print("model trained")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 114s 140ms/step - Accuracy: 0.4228 - loss: 1.6144 - val_Accuracy: 0.5283 - val_loss: 1.3171 - learning_rate: 0.0010
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 115s 147ms/step - Accuracy: 0.5409 - loss: 1.2776 - val_Accuracy: 0.5935 - val_loss: 1.1294 - learning_rate: 0.0010
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 140ms/step - Accuracy: 0.5996 - loss: 1.1334 - val_Accuracy: 0.6444 - val_loss: 1.0079 - learning_rate: 0.0010
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 124s 158ms/step - Accuracy: 0.6336 - loss: 1.0401 - val_Accuracy: 0.6893 - val_loss: 0.8859 - learning_rate: 0.0010
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 110s 141ms/step - Accuracy: 0.6585 - loss: 0.9754 - val_Accuracy: 0.6875 - val_loss: 0.8914 - learning_rate: 0.0010
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - Accuracy: 0.6787 - loss: 0.9238 - val_Accuracy: 0.7062 - val_loss: 0.8617 - learning_rate: 0.0010
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - Accuracy: 0.6875 - loss: 0.8964 - val_Accuracy: 0.6698 - val_loss: 0.9916 - learning_rate: 0.0010
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - Accuracy: 0.6998 - loss: 0.8625 - val_Accuracy: 0.7361 - val_loss: 0.7738 - learning_rate: 0.0010
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 102s 131ms/step - Accuracy: 0.7091 - loss: 0.8363 - val_Accuracy: 0.6987 - val_loss: 0.8918 - learning_rate: 0.0010
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - Accuracy: 0.7199 - loss: 0.8090 - val_Accuracy: 0.7385 - val_loss: 0.7738 - learning_rate: 0.0010
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - Accuracy: 0.7255 - loss: 0.7882
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 134ms/step - Accuracy: 0.7261 - loss: 0.7905 - val_Accuracy: 0.7306 - val_loss: 0.8145 - learning_rate: 0.0010
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 134ms/step - Accuracy: 0.7504 - loss: 0.7166 - val_Accuracy: 0.7862 - val_loss: 0.6411 - learning_rate: 1.0000e-04
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - Accuracy: 0.7587 - loss: 0.6915 - val_Accuracy: 0.7919 - val_loss: 0.6092 - learning_rate: 1.0000e-04
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 120s 153ms/step - Accuracy: 0.7656 - loss: 0.6784 - val_Accuracy: 0.7917 - val_loss: 0.6161 - learning_rate: 1.0000e-04
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 136ms/step - Accuracy: 0.7676 - loss: 0.6681 - val_Accuracy: 0.7924 - val_loss: 0.6133 - learning_rate: 1.0000e-04
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 138ms/step - Accuracy: 0.7727 - loss: 0.6562 - val_Accuracy: 0.8000 - val_loss: 0.5910 - learning_rate: 1.0000e-04
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - Accuracy: 0.7725 - loss: 0.6524 - val_Accuracy: 0.7991 - val_loss: 0.5882 - learning_rate: 1.0000e-04
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 135ms/step - Accuracy: 0.7786 - loss: 0.6450 - val_Accuracy: 0.7978 - val_loss: 0.5998 - learning_rate: 1.0000e-04
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 115s 146ms/step - Accuracy: 0.7761 - loss: 0.6419 - val_Accuracy: 0.7994 - val_loss: 0.5905 - learning_rate: 1.0000e-04
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - Accuracy: 0.7816 - loss: 0.6308
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 128s 164ms/step - Accuracy: 0.7797 - loss: 0.6329 - val_Accuracy: 0.7922 - val_loss: 0.6067 - learning_rate: 1.0000e-04
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - Accuracy: 0.7823 - loss: 0.6252 - val_Accuracy: 0.8017 - val_loss: 0.5847 - learning_rate: 1.0000e-05
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 103s 132ms/step - Accuracy: 0.7843 - loss: 0.6244 - val_Accuracy: 0.8029 - val_loss: 0.5824 - learning_rate: 1.0000e-05
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 133ms/step - Accuracy: 0.7843 - loss: 0.6217 - val_Accuracy: 0.8008 - val_loss: 0.5839 - learning_rate: 1.0000e-05
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 134ms/step - Accuracy: 0.7826 - loss: 0.6231 - val_Accuracy: 0.8038 - val_loss: 0.5798 - learning_rate: 1.0000e-05
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 108s 138ms/step - Accuracy: 0.7863 - loss: 0.6208 - val_Accuracy: 0.8036 - val_loss: 0.5818 - learning_rate: 1.0000e-05
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 137ms/step - Accuracy: 0.7839 - loss: 0.6210 - val_Accuracy: 0.8043 - val_loss: 0.5765 - learning_rate: 1.0000e-05
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - Accuracy: 0.7862 - loss: 0.6194 - val_Accuracy: 0.8035 - val_loss: 0.5760 - learning_rate: 1.0000e-05
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - Accuracy: 0.7843 - loss: 0.6163 - val_Accuracy: 0.8028 - val_loss: 0.5777 - learning_rate: 1.0000e-05
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - Accuracy: 0.7861 - loss: 0.6206 - val_Accuracy: 0.8035 - val_loss: 0.5799 - learning_rate: 1.0000e-05
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 105s 134ms/step - Accuracy: 0.7854 - loss: 0.6177 - val_Accuracy: 0.8060 - val_loss: 0.5748 - learning_rate: 1.0000e-05
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 136ms/step - Accuracy: 0.7861 - loss: 0.6194 - val_Accuracy: 0.8047 - val_loss: 0.5745 - learning_rate: 1.0000e-05
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 104s 132ms/step - Accuracy: 0.7834 - loss: 0.6165 - val_Accuracy: 0.8027 - val_loss: 0.5832 - learning_rate: 1.0000e-05
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 107s 136ms/step - Accuracy: 0.7860 - loss: 0.6193 - val_Accuracy: 0.8044 - val_loss: 0.5774 - learning_rate: 1.0000e-05
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - Accuracy: 0.7843 - loss: 0.6196
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 127s 162ms/step - Accuracy: 0.7847 - loss: 0.6201 - val_Accuracy: 0.8024 - val_loss: 0.5826 - learning_rate: 1.0000e-05
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 128ms/step - Accuracy: 0.7850 - loss: 0.6165 - val_Accuracy: 0.8032 - val_loss: 0.5782 - learning_rate: 1.0000e-06
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 100s 128ms/step - Accuracy: 0.7862 - loss: 0.6176 - val_Accuracy: 0.8030 - val_loss: 0.5791 - learning_rate: 1.0000e-06
# model trained

# %%
plt.figure(figsize=(14,4))

plt.subplot(1,2,1)
plt.plot(history.history["Accuracy"],label="Train")
plt.plot(history.history["val_Accuracy"],label="Testing")
plt.title("Accuracy")
plt.xlabel("epochs")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history["loss"],label="Train_loss")
plt.plot(history.history["val_loss"],label="Val_loss")
plt.title("Loss")
plt.xlabel("epochs")
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import *
import seaborn as sns

y_pred = model.predict(x_test)
y_pred_class = np.argmax(y_pred,axis=1)
y_true = y_test.flatten()

cm = confusion_matrix(y_true,y_pred_class)

plt.figure(figsize=(10,4))
sns.heatmap(cm, annot = True , fmt = "d",
            xticklabels = class_names,
            yticklabels = class_names,
            cmap = "Blues"
           )
plt.xlabel("True Table")
plt.ylabel("Predicated table")
plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step

# %%
model.save("cifar10_cnn.h5")
print("model_saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model_saved
