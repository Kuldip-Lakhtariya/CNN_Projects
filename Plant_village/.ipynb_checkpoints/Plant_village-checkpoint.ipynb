# %%
import os

base_path = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage'

for item in os.listdir(base_path):
    item_path = os.path.join(base_path, item)
    if os.path.isdir(item_path):
        num_images = len(os.listdir(item_path))
        print(f"{item}/ — {num_images} images")
# Out:
# Pepper__bell___Bacterial_spot/ — 978 images
# Pepper__bell___healthy/ — 1478 images
# Potato___Early_blight/ — 1000 images
# Potato___healthy/ — 152 images
# Potato___Late_blight/ — 1000 images
# Tomato_Bacterial_spot/ — 2127 images
# Tomato_Early_blight/ — 1000 images
# Tomato_healthy/ — 1591 images
# Tomato_Late_blight/ — 1909 images
# Tomato_Leaf_Mold/ — 952 images
# Tomato_Septoria_leaf_spot/ — 1771 images
# Tomato_Spider_mites_Two_spotted_spider_mite/ — 1676 images
# Tomato__Target_Spot/ — 1404 images
# Tomato__Tomato_mosaic_virus/ — 373 images
# Tomato__Tomato_YellowLeaf__Curl_Virus/ — 3209 images

# %%
import os
import shutil

rogue = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage'
print(os.listdir(rogue))  # check what's inside first
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_mosaic_virus', 'Tomato__Tomato_YellowLeaf__Curl_Virus']

# %%
import tensorflow as tf

base_path = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage'

train_ds = tf.keras.utils.image_dataset_from_directory(
    base_path,
    validation_split=0.2,
    subset='training',
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    base_path,
    validation_split=0.2,
    subset='validation',
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

class_names = train_ds.class_names
print(f"Total classes: {len(class_names)}")
print(class_names)
# Out:
# Found 20619 files belonging to 15 classes.
# Using 16496 files for training.
# Found 20619 files belonging to 15 classes.
# Using 4123 files for validation.
# Total classes: 15
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
import matplotlib.pyplot as plt

# check pixel range
for images, labels in train_ds.take(1):
    print(f"Image batch shape: {images.shape}")
    print(f"Pixel range: {images.numpy().min():.0f} to {images.numpy().max():.0f}")
    print(f"Dtype: {images.dtype}")

# visualize
plt.figure(figsize=(12, 8))
for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[labels[i]], fontsize=8)
        plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# Image batch shape: (32, 224, 224, 3)
# Pixel range: 0 to 254
# Dtype: <dtype: 'float32'>

# %%
import tensorflow as tf

base_path = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage'
AUTOTUNE = tf.data.AUTOTUNE

augment = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
], name='augmentation')

train_ds = tf.keras.utils.image_dataset_from_directory(
    base_path,
    validation_split=0.2,
    subset='training',
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    base_path,
    validation_split=0.2,
    subset='validation',
    seed=42,
    image_size=(224, 224),
    batch_size=32
)

class_names = train_ds.class_names

train_ds = (train_ds
    .map(lambda x, y: (augment(x, training=True), y),
         num_parallel_calls=AUTOTUNE)
    .shuffle(500)
    .prefetch(AUTOTUNE)
)

val_ds = val_ds.prefetch(AUTOTUNE)

print(f"Classes: {len(class_names)}")
print(class_names)
# Out:
# Found 20619 files belonging to 15 classes.
# Using 16496 files for training.
# Found 20619 files belonging to 15 classes.
# Using 4123 files for validation.
# Classes: 15
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy', 'Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
#Model bulding

base_model = tf.keras.applications.EfficientNetB0(
    weights = "imagenet",
    include_top = False,
    input_shape = (224,224,3)
)

base_model.trainable  = False

inputs = tf.keras.Input(shape=(224,224,3))
x = base_model(inputs , training = False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = tf.keras.layers.Dense(15, activation = "softmax")(x)

model = tf.keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath=r'C:\Users\Admin\OneDrive\Desktop\CNN\best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_phase1 = model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 617s 998ms/step - accuracy: 0.7423 - loss: 0.9422 - val_accuracy: 0.8528 - val_loss: 0.5222
# Epoch 2/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 624s 1s/step - accuracy: 0.8731 - loss: 0.4580 - val_accuracy: 0.8896 - val_loss: 0.3794
# Epoch 3/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 561s 961ms/step - accuracy: 0.8967 - loss: 0.3654 - val_accuracy: 0.9015 - val_loss: 0.3250
# Epoch 4/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 541s 925ms/step - accuracy: 0.9105 - loss: 0.3089 - val_accuracy: 0.9154 - val_loss: 0.2835
# Epoch 5/10
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 611s 1s/step - accuracy: 0.9185 - loss: 0.2800 - val_accuracy: 0.9158 - val_loss: 0.2648
# Epoch 6/10
# ...

# %%
#Model saved
model.save(r'C:\Users\Admin\OneDrive\Desktop\CNN\best_model.keras')
print("Saved")
# Out:
# Saved

# %%
#Load the best model

model = tf.keras.models.load_model(
        r'C:\Users\Admin\OneDrive\Desktop\CNN\best_model.keras'
)

#Evaluate best accuracy and loss

loss, accuracy = model.evaluate(val_ds)
print(f"Validation accuracy : {accuracy:.4f}")
print(f"Validation loss : {loss:.4f}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - accuracy: 0.9309 - loss: 0.2126
# Validation accuracy : 0.9309
# Validation loss : 0.2126

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import *

y_true = []
y_pred = []

for images , lables in val_ds:
    pred = model.predict(images, verbose = 0)
    y_true.extend(lables.numpy())
    y_pred.extend(np.argmax(pred , axis =1))

cm = confusion_matrix(y_true,y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels = class_names)

fig,ax = plt.subplots(figsize=(14,4))
disp.plot(ax=ax, xticks_rotation = 90, colorbar = False)
plt.title('Confusion Matrix — Plant Disease Detection')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12548\2096280549.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
#See every calss accuravy
per_class = cm.diagonal() / cm.sum(axis=1)
for name, acc in zip(class_names, per_class):
    print(f"{acc:.2f}  {name}")
# Out:
# 0.97  Pepper__bell___Bacterial_spot
# 1.00  Pepper__bell___healthy
# 0.99  Potato___Early_blight
# 0.98  Potato___Late_blight
# 0.97  Potato___healthy
# 0.91  Tomato_Bacterial_spot
# 0.60  Tomato_Early_blight
# 0.92  Tomato_Late_blight
# 0.86  Tomato_Leaf_Mold
# 0.93  Tomato_Septoria_leaf_spot
# 0.88  Tomato_Spider_mites_Two_spotted_spider_mite
# 0.93  Tomato__Target_Spot
# 0.98  Tomato__Tomato_YellowLeaf__Curl_Virus
# 0.93  Tomato__Tomato_mosaic_virus
# 0.99  Tomato_healthy

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


model = tf.keras.models.load_model(
        r'C:\Users\Admin\OneDrive\Desktop\CNN\best_model.keras'
)

# %%
#let's see by which model make the prediction
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    
    efficientnet = model.get_layer('efficientnetb0')
    
    grad_model = tf.keras.models.Model(
        efficientnet.inputs,
        [efficientnet.get_layer(last_conv_layer_name).output, 
         efficientnet.output]
    )
    
    with tf.GradientTape() as tape:
        conv_outputs, effi_output = grad_model(img_array)
        x = model.get_layer('global_average_pooling2d')(effi_output)
        x = model.get_layer('dropout')(x)
        predictions = model.get_layer('dense')(x)
        
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_heatmap ( img_path , model , last_conv_layer_name , class_names):
    img = tf.keras.utils.load_img(img_path , target_size = (224,224))
    img_array = tf.keras.utils.img_to_array(img)
    img_array_expand = tf.expand_dims(img_array , 0)

    pred = model.predict(img_array_expand,verbose=0)
    pred_class = np.argmax(pred[0])
    confidence = pred[0][pred_class]
    
    heatmap = make_gradcam_heatmap(img_array_expand, model, last_conv_layer_name)

    heatmap_resized = tf.image.resize(heatmap[...,tf.newaxis],[224,224]).numpy().squeeze()

    heatmap_color = plt.cm.jet(heatmap_resized)[:,:,:3]
    superimposed = heatmap_color * 0.4 + img_array/255.0 * 0.6

    fig, axes = plt.subplots(1, 3, figsize=(14, 4))
    axes[0].imshow(img_array.astype('uint8'))
    axes[0].set_title('Original')
    axes[0].axis('off')
    
    axes[1].imshow(heatmap_resized, cmap='jet')
    axes[1].set_title('Heatmap')
    axes[1].axis('off')
    
    axes[2].imshow(superimposed)
    axes[2].set_title(f'Predicted: {class_names[pred_class]}\nConfidence: {confidence:.2%}')
    axes[2].axis('off')
    
    plt.tight_layout()
    plt.show()

last_conv_layer = [l.name for l in model.get_layer('efficientnetb0').layers 
                   if isinstance(l, tf.keras.layers.Conv2D)][-1]
print(f"Last conv layer: {last_conv_layer}")
# Out:
# Last conv layer: top_conv

# %%
#Try heatmap on any image
import os

sample_class = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage\Tomato_Early_blight'
images = os.listdir(sample_class)
sample_img = os.path.join(sample_class, images[0])
print(sample_img)
# Out:
# C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage\Tomato_Early_blight\0012b9d2-2130-4a06-a834-b1f3af34f57e___RS_Erly.B 8389.JPG

# %%
display_heatmap(sample_img, model, 'top_conv', class_names)

# %%
sample_class2 = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage\Pepper__bell___healthy'
images2 = os.listdir(sample_class2)
sample_img2 = os.path.join(sample_class2, images2[0])
display_heatmap(sample_img2, model, 'top_conv', class_names)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000000238418578].

# %%
sample_class3 = r'C:\Users\Admin\OneDrive\Desktop\CNN\plantvillage\Tomato__Tomato_YellowLeaf__Curl_Virus'
images3 = os.listdir(sample_class3)
sample_img3 = os.path.join(sample_class3, images3[0])
display_heatmap(sample_img3, model, 'top_conv', class_names)
